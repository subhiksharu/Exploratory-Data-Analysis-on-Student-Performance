# %% [markdown]
# <a href="https://colab.research.google.com/github/subhiksharu/Exploratory-Data-Analysis-on-Student-Performance/blob/main/Student%20Performance%20EDA%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("student_performance_dataset.csv")
df.head()
# Out:
#   student_id  gender  age  study_hours_per_day  attendance_percentage  \
# 0       S001  Female   16                  4.5                     92
# 1       S002    Male   17                  2.0                     75
# 2       S003  Female   16                  5.0                     95
# 3       S004    Male   18                  1.5                     68
# 4       S005  Female   17                  3.5                     88
#
#    previous_marks  final_score parental_education internet_access  \
# 0              78           84           Bachelor             Yes
# 1              60           63        High School             Yes
# 2              85           90             Master             Yes
# 3              52           55        High School              No
# 4              72           76           Bachelor             Yes
#
#   extra_classes  sleep_hours
# 0           Yes          7.5
# 1            No          6.0
# 2           Yes          8.0
# ...

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             60 non-null     object
#  1   gender                 60 non-null     object
#  2   age                    60 non-null     int64
#  3   study_hours_per_day    60 non-null     float64
#  4   attendance_percentage  60 non-null     int64
#  5   previous_marks         60 non-null     int64
#  6   final_score            60 non-null     int64
#  7   parental_education     60 non-null     object
#  8   internet_access        60 non-null     object
#  9   extra_classes          60 non-null     object
#  10  sleep_hours            60 non-null     float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 5.3+ KB
#              age  study_hours_per_day  attendance_percentage  previous_marks  \
# ...

# %%
df.isnull().sum()
# Out:
# student_id               0
# gender                   0
# age                      0
# study_hours_per_day      0
# attendance_percentage    0
# previous_marks           0
# final_score              0
# parental_education       0
# internet_access          0
# extra_classes            0
# sleep_hours              0
# dtype: int64

# %%
df["final_score"].mean()
# Out:
# np.float64(73.88333333333334)

# %%
df["final_score"].max()
df["final_score"].min()
# Out:
# 45

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=df, x="study_hours_per_day", y="final_score")
plt.title("Study Hours vs Final Score")
plt.show()

# %%
sns.scatterplot(data=df, x="attendance_percentage", y="final_score")
plt.title("Attendance vs Final Score")
plt.show()

# %%
sns.barplot(data=df, x="parental_education", y="final_score")
plt.title("Average Score by Parental Education")
plt.show()

# %%
numeric_df = df.select_dtypes(include="number")

sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
